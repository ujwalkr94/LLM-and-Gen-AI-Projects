# %%
from __future__ import annotations

import operator
from typing import TypedDict, List, Annotated

from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage
from dotenv import load_dotenv

# %%
load_dotenv(dotenv_path=r"E:\Desktop\Data_Science\Gen_AI\.env")
# Out:
# True

# %%
class Task(BaseModel):
    id: int
    title: str
    brief: str = Field(..., description="What to cover")

# %%
class Plan(BaseModel):
    blog_title: str
    tasks: List[Task]

# %%
class State(TypedDict):
    topic: str
    plan: Plan
    # reducer: results from workers get concatenated automatically
    sections: Annotated[List[str], operator.add]
    final: str

# %%
llm = ChatOpenAI(model="gpt-4.1-mini")

# %%
def orchestrator(state: State) -> dict:

    plan = llm.with_structured_output(Plan).invoke(
        [
            SystemMessage(
                content=(
                    "Create a blog plan with 5-7 sections on the following topic."
                )
            ),
            HumanMessage(content=f"Topic: {state['topic']}"),
        ]
    )
    return {"plan": plan}

# %%
def fanout(state: State):
    return [Send("worker", {"task": task, "topic": state["topic"], "plan": state["plan"]})
            for task in state["plan"].tasks]

# %%
def worker(payload: dict) -> dict:

    # payload contains what we sent
    task = payload["task"]
    topic = payload["topic"]
    plan = payload["plan"]

    blog_title = plan.blog_title

    section_md = llm.invoke(
        [
            SystemMessage(content="Write one clean Markdown section."),
            HumanMessage(
                content=(
                    f"Blog: {blog_title}\n"
                    f"Topic: {topic}\n\n"
                    f"Section: {task.title}\n"
                    f"Brief: {task.brief}\n\n"
                    "Return only the section content in Markdown."
                )
            ),
        ]
    ).content.strip()

    return {"sections": [section_md]}

# %%
from pathlib import Path

def reducer(state: State) -> dict:
    
    title = state["plan"].blog_title
    body = "\n\n".join(state["sections"]).strip()

    final_md = f"# {title}\n\n{body}\n"

    # ---- save to file ----
    filename = title.lower().replace(" ", "_") + ".md"
    output_path = Path(filename)
    output_path.write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
g = StateGraph(State)
g.add_node("orchestrator", orchestrator)
g.add_node("worker", worker)
g.add_node("reducer", reducer)

# %%
g.add_edge(START, "orchestrator")
g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()

app

# %%
out = app.invoke({"topic": "Write a blog on Self Attention", "sections": []})

# %%
out
# Out:
# {'topic': 'Write a blog on Self Attention',
#  'plan': Plan(blog_title='Understanding Self-Attention: The Backbone of Modern Neural Networks', tasks=[Task(id=1, title='Introduction to Self-Attention', brief='Explain what self-attention is and why it is important in the context of neural networks and deep learning.'), Task(id=2, title='The Mechanics of Self-Attention', brief='Describe how self-attention works internally, including the concepts of queries, keys, and values.'), Task(id=3, title='Self-Attention vs. Traditional Attention Mechanisms', brief='Compare self-attention with traditional attention mechanisms and highlight the advantages of self-attention.'), Task(id=4, title='Applications of Self-Attention', brief='Discuss the various applications of self-attention in natural language processing, computer vision, and other domains.'), Task(id=5, title='Self-Attention in Transformer Models', brief='Explore the role of self-attention in transformer architectures and why it has revolutionized deep learning.'), Task(id=6, title='Challenges and Limitations of Self-Attention', brief='Address some challenges and computational limitations associated with self-attention mechanisms.'), Task(id=7, title='Future Directions and Conclusion', brief='Conclude with emerging research trends and potential future improvements related to self-attention.')]),
#  'sections': ['## Introduction to Self-Attention\n\nSelf-attention is a powerful mechanism in neural networks that enables the model to weigh the importance of different parts of the input data relative to each other. Unlike traditional methods that process input sequences sequentially, self-attention considers the entire sequence simultaneously, allowing the model to capture long-range dependencies and relationships within the data.\n\nIn the context of deep learning, especially in natural language processing (NLP) and computer vision, self-attention has revolutionized how models understand context and structure. It forms the backbone of transformer architectures, which have achieved state-of-the-art results across various tasks, from machine translation to image recognition.\n\nBy dynamically focusing on relevant information within a sequence, self-attention improves the model’s ability to represent complex patterns, enhances learning efficiency, and reduces the need for extensive manual feature engineering. This makes it an essential component for building modern, high-performing neural networks.',
#   "## The Mechanics of Self-Attention\n\nAt its core, self-attention is a mechanism that allows a neural network to weigh the importance of different parts of an input sequence relative to each other. This capability is essential for understanding context and relationships within data such as sentences, where the meaning of a word depends heavily on other words around it.\n\nSelf-attention works by transforming the input data into three distinct vectors: **queries (Q)**, **keys (K)**, and **values (V)**. These vectors are generated through learned linear projections of the input embeddings. Here's how each component functions:\n\n- **Queries (Q):** Represent the element for which the attention is being calculated. Think of a query as a question that seeks relevant information from other parts of the sequence.\n- **Keys (K):** Represent each element against which the query is compared to find relevance.\n- **Values (V):** Contain the actual information or content that will be aggregated based on the attention scores.\n\nThe process proceeds as follows:\n\n1. **Scoring:** For each query, the model computes a compatibility score with all keys. This is typically done using the dot product between the query and each key vector. A higher score indicates greater relevance or similarity.\n\n2. **Scaling:** To prevent large dot product values from causing instability in gradients, the scores are scaled down by dividing by the square root of the dimension of the key vectors.\n\n3. **Softmax Normalization:** The scaled scores are passed through a softmax function, converting them into a probability distribution. This step ensures that the attention weights sum to one and highlight the most relevant parts of the input sequence.\n\n4. **Weighted Sum:** The attention weights are then used to compute a weighted sum of the value vectors. This aggregation produces an output vector for each position in the sequence that reflects contextual information from the entire input.\n\nMathematically, the self-attention output can be expressed as:\n\n```\nAttention(Q, K, V) = softmax((Q × Kᵀ) / √d_k) × V\n```\n\nwhere `d_k` is the dimension of the key vectors.\n\nBy repeating this process for every element in the sequence, the model effectively captures dependencies regardless of their distance apart, enabling it to understand context dynamically. This powerful mechanism forms the backbone of many state-of-the-art architectures, such as the Transformer, which have revolutionized natural language processing and beyond.",
#   '## Self-Attention vs. Traditional Attention Mechanisms\n\nTraditional attention mechanisms in neural networks often operate between two different sequences, such as in sequence-to-sequence models where the decoder attends to the encoder’s output. This form of attention helps the model selectively focus on relevant parts of an input sequence when generating each element of the output sequence. While effective, it inherently relies on two separate data streams: queries and keys/values come from different sources.\n\nSelf-attention, on the other hand, allows a sequence to attend to itself by computing attention scores within the same input. Each element in the sequence dynamically weighs the importance of every other element, capturing both local and global dependencies simultaneously. This approach brings several key advantages:\n\n- **Parallelization:** Unlike traditional recurrent models that process data sequentially, self-attention enables parallel computation across all positions in the input. This significantly speeds up training and inference.\n\n- **Long-Range Dependency Modeling:** Self-attention can directly connect distant positions in the sequence, making it easier to capture relationships between far-apart elements without the degradation issues common in RNNs.\n\n- **Flexibility:** Since self-attention treats the input as a set of queries, keys, and values from the same source, it can be applied to a wide range of tasks beyond translation, including language modeling, image recognition, and more.\n\n- **Scalability:** Self-attention scales well with data size and model capacity, enabling the creation of very large architectures like Transformers, which have revolutionized natural language processing and other fields.\n\nIn summary, while traditional attention mechanisms laid the groundwork for selective focus in neural networks, self-attention extends this concept by enabling a richer, more efficient, and scalable way to model complex relationships within the data itself. This makes self-attention the backbone of many state-of-the-art models today.',
#   "## Applications of Self-Attention\n\nSelf-attention has revolutionized several fields by enabling models to dynamically focus on different parts of the input, thereby capturing complex dependencies and relationships. Below are some key applications across various domains:\n\n### Natural Language Processing (NLP)\n- **Machine Translation:** Self-attention allows models like the Transformer to understand context by attending to all parts of a sentence simultaneously, improving translation accuracy.\n- **Text Summarization:** Models can identify and emphasize important phrases or sentences, generating concise summaries.\n- **Sentiment Analysis:** By focusing on sentiment-bearing words, self-attention aids in accurately capturing emotional tone.\n- **Question Answering:** Enables the model to find and relate relevant pieces of information from the text to answer questions effectively.\n\n### Computer Vision\n- **Image Classification:** Self-attention mechanisms help models focus on crucial regions in images, enhancing classification performance.\n- **Object Detection:** Attention facilitates the identification and localization of multiple objects within complex scenes.\n- **Image Generation and Enhancement:** Used in generative models to create or improve images by concentrating on significant patterns and textures.\n\n### Other Domains\n- **Speech Recognition:** Improves the modeling of temporal dependencies and contextual cues in audio signals.\n- **Recommender Systems:** Helps in understanding user preferences by attending to relevant past behaviors and interactions.\n- **Graph Neural Networks:** Self-attention enables nodes to weigh the importance of their neighbors, improving representation learning on graph-structured data.\n\nIn summary, self-attention's flexibility in capturing long-range and context-aware relationships makes it a fundamental component in a wide array of modern AI applications.",
#   '## Self-Attention in Transformer Models\n\nSelf-attention is the core mechanism that powers transformer architectures, fundamentally transforming how deep learning models process and understand data. Unlike traditional sequence models, such as RNNs or CNNs, which handle input data sequentially or locally, self-attention enables the model to weigh the importance of every element within the input sequence simultaneously. This allows the transformer to capture long-range dependencies and contextual relationships more effectively.\n\nIn a transformer, self-attention works by mapping a set of input vectors (representations of tokens, for example) into three distinct vectors: queries, keys, and values. The attention mechanism computes a compatibility score between the query and all keys, normalizes these scores with a softmax function, and then uses the resulting weights to generate a weighted sum of the values. This weighted sum becomes the output for that particular position, dynamically integrating information from the entire sequence.\n\nThis parallelizable approach drastically reduces training times compared to sequential models and opens the door to scaling models to billions of parameters. More importantly, self-attention facilitates greater flexibility: the model can focus on the most relevant parts of the input for each position, capturing nuanced dependencies such as syntax in language processing or relationships in images.\n\nBy enabling efficient, scalable, and context-aware processing, self-attention has revolutionized deep learning. It is the backbone of many state-of-the-art models in natural language processing, computer vision, and beyond, making transformers the gold standard for many AI tasks today.',
#   '## Challenges and Limitations of Self-Attention\n\nWhile self-attention has revolutionized neural network architectures, especially in natural language processing and computer vision, it is not without its challenges and limitations. One primary issue is its computational complexity. Self-attention requires calculating interactions between every pair of elements in the input sequence, leading to a quadratic time and memory complexity with respect to the sequence length. This makes it resource-intensive and less scalable for very long sequences, limiting its practicality in tasks involving extensive inputs.\n\nAnother challenge is related to interpretability. Although self-attention provides weights indicating the importance of different tokens relative to each other, these weights can sometimes be difficult to interpret or may not clearly reflect the model’s decision-making process. This limits transparency, which is critical in sensitive applications.\n\nMoreover, self-attention mechanisms can struggle with capturing very long-range dependencies in sequences if not properly designed, as positional encoding and model depth play crucial roles in maintaining context over extended inputs.\n\nFinally, training large self-attention models demands substantial computational resources, which can be a barrier for research groups and organizations with limited hardware. Despite ongoing research into efficient attention variants and sparse attention mechanisms, these challenges present important considerations when designing and deploying self-attention-based models.',
#   '## Future Directions and Conclusion\n\nSelf-attention has undeniably revolutionized modern neural network architectures, particularly in natural language processing and computer vision. As research advances, several promising directions are emerging to enhance its efficiency, scalability, and applicability.\n\nOne key area of focus is **efficient self-attention mechanisms** designed to reduce the quadratic complexity associated with traditional self-attention layers. Approaches such as sparse attention, linearized attention, and memory-compressed attention aim to make self-attention viable for longer sequences and larger datasets without compromising performance.\n\nAnother exciting frontier is the integration of **multimodal self-attention models** that process and relate information across diverse data types, including text, images, and audio. This could unlock more holistic and context-aware AI systems capable of understanding complex, real-world scenarios.\n\nMoreover, researchers are exploring **adaptive and dynamic attention frameworks**, which adjust their attention patterns based on the task or input, potentially improving model interpretability and efficiency.\n\nIn conclusion, self-attention remains a dynamic and fertile field of study. As models continue to evolve, future improvements promise greater flexibility, scalability, and deeper understanding, paving the way for more powerful and generalizable AI systems. Staying abreast of these developments is crucial for anyone looking to harness the full potential of modern neural networks.'],
#  'final': "# Understanding Self-Attention: The Backbone of Modern Neural Networks\n\n## Introduction to Self-Attention\n\nSelf-attention is a powerful mechanism in neural networks that enables the model to weigh the importance of different parts of the input data relative to each other. Unlike traditional methods that process input sequences sequentially, self-attention considers the entire sequence simultaneously, allowing the model to capture long-range dependencies and relationships within the data.\n\nIn the context of deep learning, especially in natural language processing (NLP) and computer vision, self-attention has revolutionized how models understand context and structure. It forms the backbone of transformer architectures, which have achieved state-of-the-art results across various tasks, from machine translation to image recognition.\n\nBy dynamically focusing on relevant information within a sequence, self-attention improves the model’s ability to represent complex patterns, enhances learning efficiency, and reduces the need for extensive manual feature engineering. This makes it an essential component for building modern, high-performing neural networks.\n\n## The Mechanics of Self-Attention\n\nAt its core, self-attention is a mechanism that allows a neural network to weigh the importance of different parts of an input sequence relative to each other. This capability is essential for understanding context and relationships within data such as sentences, where the meaning of a word depends heavily on other words around it.\n\nSelf-attention works by transforming the input data into three distinct vectors: **queries (Q)**, **keys (K)**, and **values (V)**. These vectors are generated through learned linear projections of the input embeddings. Here's how each component functions:\n\n- **Queries (Q):** Represent the element for which the attention is being calculated. Think of a query as a question that seeks relevant information from other parts of the sequence.\n- **Keys (K):** Represent each element against which the query is compared to find relevance.\n- **Values (V):** Contain the actual information or content that will be aggregated based on the attention scores.\n\nThe process proceeds as follows:\n\n1. **Scoring:** For each query, the model computes a compatibility score with all keys. This is typically done using the dot product between the query and each key vector. A higher score indicates greater relevance or similarity.\n\n2. **Scaling:** To prevent large dot product values from causing instability in gradients, the scores are scaled down by dividing by the square root of the dimension of the key vectors.\n\n3. **Softmax Normalization:** The scaled scores are passed through a softmax function, converting them into a probability distribution. This step ensures that the attention weights sum to one and highlight the most relevant parts of the input sequence.\n\n4. **Weighted Sum:** The attention weights are then used to compute a weighted sum of the value vectors. This aggregation produces an output vector for each position in the sequence that reflects contextual information from the entire input.\n\nMathematically, the self-attention output can be expressed as:\n\n```\nAttention(Q, K, V) = softmax((Q × Kᵀ) / √d_k) × V\n```\n\nwhere `d_k` is the dimension of the key vectors.\n\nBy repeating this process for every element in the sequence, the model effectively captures dependencies regardless of their distance apart, enabling it to understand context dynamically. This powerful mechanism forms the backbone of many state-of-the-art architectures, such as the Transformer, which have revolutionized natural language processing and beyond.\n\n## Self-Attention vs. Traditional Attention Mechanisms\n\nTraditional attention mechanisms in neural networks often operate between two different sequences, such as in sequence-to-sequence models where the decoder attends to the encoder’s output. This form of attention hel ...
