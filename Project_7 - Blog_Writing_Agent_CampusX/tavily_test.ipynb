# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv(dotenv_path=r"E:\Desktop\Data_Science\Gen_AI\.env")
# Out:
# True

# %%
tool = TavilySearchResults(max_results=2)
results = tool.invoke({"query": 'ChatGPT version releases and updates from 2022 to 2026'})
results
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17012\1187185310.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=2)
# [{'title': 'ChatGPT - Wikipedia',
#   'url': 'https://en.wikipedia.org/wiki/ChatGPT',
#   'content': '| Version | Release date | Status in ChatGPT | Description |\n| GPT-3.5 | November 2022 | Discontinued | The first model used in ChatGPT. |\n| GPT-4 | March 2023 | Discontinued | Larger than GPT-3.5 and quickly integrated into Microsoft products like Bing. OpenAI later added the ability to analyze images. |\n| GPT-4o | May 2024 | Discontinued | Capable of processing text, image, audio, and video, GPT-4o is faster and more capable than GPT-4. Its removal from ChatGPT led to backlash from users attached to its personality. |\n| GPT-4o mini | July 2024 | Discontinued | A smaller and cheaper version of GPT-4o. GPT-4o mini replaced GPT-3.5 in the July 2024 version of ChatGPT. |\n| o1-preview | September 2024 | Discontinued | A pre-release version of OpenAI o1, an early reasoning model. | [...] | GPT-4.1 mini | April 2025 | Discontinued | A smaller version of GPT-4.1. Originally launched in the OpenAI API in April 2025. GPT-4.1 mini replaced GPT-4o mini in the May 2025 version of ChatGPT. |\n| o3 | April 2025 | Legacy support | The full release of the o3 model, offering improved reasoning and performance compared to earlier "o" series models |\n| o4-mini | April 2025 | Discontinued |  |\n| o4-mini-high | April 2025 | Discontinued |  |\n| o3-pro | June 2025 | Discontinued | A version of o3 which uses more compute to get better results. | [...] | o1-mini | September 2024 | Discontinued | A smaller and faster version of OpenAI o1. |\n| o1 | December 2024 | Discontinued | The full release of OpenAI o1, which had previously been available as a preview. |\n| o1-pro | December 2024 | Discontinued | A version of o1 which uses more compute. |\n| o3-mini | January 2025 | Discontinued | Successor of o1-mini. |\n| o3-mini-high | January 2025 | Discontinued | Variant of o3-mini using more compute. |\n| GPT-4.5 | February 2025 | Discontinued | Particularly large GPT model. Promoted by Altman as OpenAI\'s "last non-chain-of-thought model". |\n| GPT-4.1 | April 2025 | Discontinued | First launched in the OpenAI API in April 2025, GPT-4.1 was later added to ChatGPT in May 2025. |',
#   'score': 0.9996923},
#  {'title': '4 Big Changes Coming To ChatGPT In 2026 - AOL.com',
#   'url': 'https://www.aol.com/articles/4-big-changes-coming-chatgpt-035525765.html',
#   'content': "On February 13, 2026, OpenAI will be retiring six models in one go. The AI giant will discontinue the following models: GPT-5 (Instant and Thinking), GPT-4o, GPT-4.1, GPT-4.1 mini, and OpenAI o4-mini. These models will be removed from ChatGPT, though they'll remain available through OpenAI's API. From that date onward, GPT-5.2 will be the default model for all ChatGPT users.",
#   'score': 0.9996567}]

# %%
for r in results:
    print(r['content'])
# Out:
# | Version | Release date | Status in ChatGPT | Description |
# | GPT-3.5 | November 2022 | Discontinued | The first model used in ChatGPT. |
# | GPT-4 | March 2023 | Discontinued | Larger than GPT-3.5 and quickly integrated into Microsoft products like Bing. OpenAI later added the ability to analyze images. |
# | GPT-4o | May 2024 | Discontinued | Capable of processing text, image, audio, and video, GPT-4o is faster and more capable than GPT-4. Its removal from ChatGPT led to backlash from users attached to its personality. |
# | GPT-4o mini | July 2024 | Discontinued | A smaller and cheaper version of GPT-4o. GPT-4o mini replaced GPT-3.5 in the July 2024 version of ChatGPT. |
# | o1-preview | September 2024 | Discontinued | A pre-release version of OpenAI o1, an early reasoning model. | [...] | GPT-4.1 mini | April 2025 | Discontinued | A smaller version of GPT-4.1. Originally launched in the OpenAI API in April 2025. GPT-4.1 mini replaced GPT-4o mini in the May 2025 version of ChatGPT. |
# | o3 | April 2025 | Legacy support | The full release of the o3 model, offering improved reasoning and performance compared to earlier "o" series models |
# | o4-mini | April 2025 | Discontinued |  |
# | o4-mini-high | April 2025 | Discontinued |  |
# | o3-pro | June 2025 | Discontinued | A version of o3 which uses more compute to get better results. | [...] | o1-mini | September 2024 | Discontinued | A smaller and faster version of OpenAI o1. |
# | o1 | December 2024 | Discontinued | The full release of OpenAI o1, which had previously been available as a preview. |
# | o1-pro | December 2024 | Discontinued | A version of o1 which uses more compute. |
# | o3-mini | January 2025 | Discontinued | Successor of o1-mini. |
# | o3-mini-high | January 2025 | Discontinued | Variant of o3-mini using more compute. |
# | GPT-4.5 | February 2025 | Discontinued | Particularly large GPT model. Promoted by Altman as OpenAI's "last non-chain-of-thought model". |
# | GPT-4.1 | April 2025 | Discontinued | First launched in the OpenAI API in April 2025, GPT-4.1 was later added to ChatGPT in May 2025. |
# On February 13, 2026, OpenAI will be retiring six models in one go. The AI giant will discontinue the following models: GPT-5 (Instant and Thinking), GPT-4o, GPT-4.1, GPT-4.1 mini, and OpenAI o4-mini. These models will be removed from ChatGPT, though they'll remain available through OpenAI's API. From that date onward, GPT-5.2 will be the default model for all ChatGPT users.
